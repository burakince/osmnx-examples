# %%
import osmnx as ox
# %matplotlib inline
ox.config(log_console=True)
ox.__version__
# Out:
# '0.16.1'

# %%
filepath = './data/london.graphml'
G = ox.load_graphml(filepath)

# %%
fig, ax = ox.plot_graph(G, node_color='r')

# %%
df = ox.graph_to_gdfs(G)

# %%
df
# Out:
# (                    y         x       osmid   highway  ref  \
#  78112       51.526976 -0.145792       78112       NaN  NaN
#  99880       51.525085 -0.153580       99880       NaN  NaN
#  99884       51.524364 -0.152816       99884       NaN  NaN
#  99907       51.524890 -0.156967       99907       NaN  NaN
#  99908       51.525051 -0.157272       99908       NaN  NaN
#  ...               ...       ...         ...       ...  ...
#  8013705207  51.601983 -0.407172  8013705207       NaN  NaN
#  8013705208  51.602042 -0.407129  8013705208  crossing  NaN
#  8013705238  51.602646 -0.409739  8013705238       NaN  NaN
#  8013705239  51.602776 -0.409611  8013705239       NaN  NaN
#  8013705240  51.602702 -0.409686  8013705240  crossing  NaN
#
#                               geometry
#  78112       POINT (-0.14579 51.52698)
#  99880       POINT (-0.15358 51.52508)
#  99884       POINT (-0.15282 51.52436)
#  99907       POINT (-0.15697 51.52489)
#  99908       POINT (-0.15727 51.52505)
# ...
